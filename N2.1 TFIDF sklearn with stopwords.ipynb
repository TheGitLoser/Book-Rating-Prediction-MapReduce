# %%
import pandas as pd 
import numpy as np 
from sklearn.preprocessing import MultiLabelBinarizer   # one-hot encoding
from sklearn.feature_extraction.text import TfidfVectorizer     # TF-IDF
from sklearn.feature_extraction import text     # for stopwords

from sklearn.model_selection import train_test_split
from sklearn.metrics import mean_squared_error

import tensorflow as tf
from tensorflow import keras
from tensorflow.keras import layers

import time
import matplotlib.pyplot as plt

# path to files
trainingDataFile = "./Train_data.csv"
evaluateDataFile = "./Test_data.csv"

# store preprocessing model
encoder = {}

def isFloat(value):
    try:
        float(value)
        return True
    except:
        return False
def isInt(value):
    try:
        int(value)
        return True
    except:
        return False
def groupByLanguage(language):
    # en-US, en-GB, en-CA -> eng
    if language in ['en-US', 'en-GB', 'en-CA']:
        language = 'eng'
    return language

# for training data
def fitTransformByMultiLableBinarizer(trainData, columnName):
    global encoder
    encoder[columnName] = MultiLabelBinarizer()
    temp = trainData[columnName].apply(lambda x: set([" ".join(w.strip().lower().split()) for w in str(x).split("/")]))   # split words by "/" to list, remove duplicated whitespace

    tempValue = encoder[columnName].fit_transform(temp)
    tempColumnName = np.char.add(columnName+"=", encoder[columnName].classes_.tolist())
    
    # concat to original dataframe
    trainData = pd.concat([trainData.drop(columnName, axis=1), pd.DataFrame(tempValue, columns=tempColumnName).set_index(trainData[columnName].index)], axis=1)   
    return trainData

def fitTransformByTFIDF(trainData, columnName):
    global encoder
    encoder[columnName] = TfidfVectorizer(stop_words=text.ENGLISH_STOP_WORDS)

    tempValue = encoder[columnName].fit_transform(trainData[columnName]).toarray()
    tempColumnName = np.char.add(columnName+"=", encoder[columnName].get_feature_names())

    # concat to original dataframe
    trainData = pd.concat([trainData.drop(columnName, axis=1), pd.DataFrame(tempValue, columns=tempColumnName).set_index(trainData[columnName].index)], axis=1)
    return trainData


# for testing data
def transformByMultiLableBinarizer(testData, columnName):
    global encoder
    temp = testData[columnName].apply(lambda x: set([" ".join(w.strip().lower().split()) for w in str(x).split("/")]))    # split words by "/" to list, remove duplicated whitespace

    tempValue = encoder[columnName].transform(temp)
    tempColumnName = np.char.add(columnName+"=", encoder[columnName].classes_.tolist())
    
    # concat to original dataframe
    testData = pd.concat([testData.drop(columnName, axis=1), pd.DataFrame(tempValue, columns=tempColumnName).set_index(testData[columnName].index)], axis=1)
    return testData

def transformByTFIDF(testData, columnName):
    global encoder
    tempValue = encoder[columnName].transform(testData[columnName]).toarray()
    tempColumnName = np.char.add(columnName+"=", encoder[columnName].get_feature_names())

    # concat to original dataframe
    testData = pd.concat([testData.drop(columnName, axis=1), pd.DataFrame(tempValue, columns=tempColumnName).set_index(testData[columnName].index)], axis=1)
    return testData

# %% [markdown]
# ## Data cleaning

# %%
def dataCleaning(data):
    # remove white spaces of column's name
    data.columns = data.columns.str.strip()

    # remove record if target is not float
    data = data[data['average_rating'].apply(lambda x: isFloat(x))]
    data = data[pd.to_numeric(data['average_rating'])<=5]

    # remove record if value is not integer 
    data = data[data['isbn'].apply(lambda x: isInt(x))]
    data = data[data['num_pages'].apply(lambda x: isInt(x))]
    data = data[data['ratings_count'].apply(lambda x: isInt(x))]
    data = data[data['text_reviews_count'].apply(lambda x: isInt(x))]

    return data

# %% [markdown]
# ## Preprocess of training data

# %%
def preprocessTrainData(trainData):
    global encoder
    # remove white spaces of column's name
    trainData.columns = trainData.columns.str.strip()
   
    # if language_code = en-US/en-GB/en-CA -> eng
    trainData['language_code'] = trainData['language_code'].apply(lambda x: groupByLanguage(x))
    
    # split publication_date
    trainData['publication_date'] = pd.to_datetime(trainData['publication_date'], format = "%m/%d/%Y", errors='coerce')
    trainData['publication_date_year'] = trainData['publication_date'].dt.year
    trainData['publication_date_month'] = trainData['publication_date'].dt.month
    trainData['publication_date_week'] = trainData['publication_date'].dt.week
    trainData['publication_date_day'] = trainData['publication_date'].dt.day
    # drop row if one value is null, eg bookID#45531's date = 6/31/1982
    trainData = trainData[trainData.isna().any(axis=1) == False]

    # chage dtype
    trainData = trainData.astype({'title': 'U', 'text_reviews_count': float})

    # drop if duplicated, isbn should be unique
    trainData = trainData[trainData['isbn'].duplicated() == False]

    # drop useless column
    trainData.drop(['isbn', 'isbn13', 'publication_date'], axis=1, inplace=True)

    # one hot encoding of authors & language_code & publisher 
    trainData = fitTransformByMultiLableBinarizer(trainData, 'authors')
    trainData = fitTransformByMultiLableBinarizer(trainData, 'language_code')
    trainData = fitTransformByMultiLableBinarizer(trainData, 'publisher')

    # encode title
    trainData = fitTransformByTFIDF(trainData, 'title')

    return trainData.fillna(0)

# %% [markdown]
# ## Preprocess of testing / predict data

# %%
def preprocessTestData(testData):
    global encoder 
    # remove white spaces of column's name
    testData.columns = testData.columns.str.strip()

    # if language_code = en-US, en-GB, en-CA -> eng
    testData['language_code'] = testData['language_code'].apply(lambda x: groupByLanguage(x))

    # split publication_date
    testData['publication_date'] = pd.to_datetime(testData['publication_date'], format = "%m/%d/%Y", errors='coerce')
    testData['publication_date_year'] = testData['publication_date'].dt.year
    testData['publication_date_month'] = testData['publication_date'].dt.month
    testData['publication_date_week'] = testData['publication_date'].dt.week
    testData['publication_date_day'] = testData['publication_date'].dt.day

    # chage dtype
    testData = testData.astype({'title': 'U', 'text_reviews_count': float})

    # drop useless column
    testData.drop(['isbn', 'isbn13', 'publication_date'], axis=1, inplace=True)


    # one hot encoding of authors & language_code & publisher 
    testData = transformByMultiLableBinarizer(testData, 'authors')
    testData = transformByMultiLableBinarizer(testData, 'language_code')
    testData = transformByMultiLableBinarizer(testData, 'publisher')

    # encode title
    testData = transformByTFIDF(testData, 'title')

    return testData.fillna(0)

# %% [markdown]
# ## Import data
# ## Split data into train & test

# %%
trainingData = pd.read_csv(trainingDataFile).set_index('bookID')
evaluatingData = pd.read_csv(evaluateDataFile).set_index('bookID')

trainingData = dataCleaning(trainingData)

# spliting data
trainData, testData = train_test_split(trainingData, test_size=0.3, random_state=42)


# preprocessing
trainData = preprocessTrainData(trainData)

testData = preprocessTestData(testData)
evaluateData = preprocessTestData(evaluatingData)

print(f'trainData: {trainData.shape}')
print(f'testData: {testData.shape}')
print(f'evaluateData: {evaluateData.shape}', end='\n\n')
print('Shape checking: ', trainData.shape[1]==testData.shape[1] & trainData.shape[1]==evaluateData.shape[1], end='\n\n\n\n')

def splitXY(data):
    tempX = data.drop('average_rating', axis=1)
    tempY = data['average_rating']
    print(tempX.shape, tempY.shape)
    return tempX, tempY

# split to X, y
XTrain, yTrain = splitXY(trainData)
XTest, yTest = splitXY(testData)
XEvaluate, yEvaluate = splitXY(evaluateData)


# evaluateData.info()
# Out:
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   import sys
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:10: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   # Remove the CWD from sys.path while we load stuff.
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:11: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   # This is added back by InteractiveShellApp.init_path()
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:12: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   if sys.path[0] == '':
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:13: FutureWarning: Series.dt.weekofyear and Series.dt.week have been deprecated.  Please use Series.dt.isocalendar().week instead.
#   del sys.path[0]
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:13: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   del sys.path[0]
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:14: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   import sys
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:10: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   # Remove the CWD from sys.path while we load stuff.
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:11: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   # This is added back by InteractiveShellApp.init_path()
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:12: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   if sys.path[0] == '':
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:13: FutureWarning: Series.dt.weekofyear and Series.dt.week have been deprecated.  Please use Series.dt.isocalendar().week instead.
#   del sys.path[0]
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:13: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   del sys.path[0]
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:14: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# /usr/local/lib/python3.6/dist-packages/sklearn/preprocessing/_label.py:987: UserWarning: unknown class(es) ['a.j. ayer', 'a.j. mcallister', 'a.r. taylor', 'a.v. miller', 'abbe wool', 'abbie hoffman', 'abigail thomas', 'adam gauntlett', 'adam mansbach', 'adam phillips', 'adi granov', 'adrian reynolds', 'adrián ferrero', 'aeon j. skoble', 'agnes d. kingston', 'agnolo di cosimo bronzino', 'aimé césaire', 'alain korkos', 'alan cohen', 'alan jay lerner', 'alan jolis', 'alan myers', 'alastair hamilton', 'alastair mcewen', 'albert marrin', 'albert speer', 'alev lytle croutier', 'alex austin', 'alex cox', "alex prud'homme", 'alexander nehamas', 'alexandre dumas fils', 'alfred siewers', 'ali vali', 'alice mayhew', 'alicia suskin ostriker', 'alisa freedman', 'alison lurie', 'alison pace', 'alistair horne', 'alistair moffat', 'allan c. weisbecker', 'allan ulrich', 'allan zola kronzek', 'allen w. wood', 'amy carter', 'ana alcaina', 'anca munteanu', 'ande parks', 'andre dubus', 'andre duza', 'andreas gursky', 'andrew brown', 'andrew carnegie', 'andrew cartmel', 'andrew heintzman', 'andrew helfer', 'andrew m. greeley', 'andrew p. trout', 'andrew s. becker', 'andy mcnab', 'angela scholar', 'angela zeman', 'anita desai', 'anita hoffman', 'ann abramson', 'ann druyan', 'ann dunnigan', 'ann granger', 'ann hewetson', 'ann major', 'ann thompson', 'anna brailovsky', 'anna paterson', 'anna tambour', 'anne chisholm', 'anne perry', 'anne rampling', 'annette lavers', 'anri itō', 'anselm of canterbury', 'anthony decurtis', 'anthony minghella', 'anthony quinton', 'anthony rizcallah ferris', 'anthony thwaite', 'antonia juhasz', 'antonio gramsci', 'apostolos n. athanassakis', 'april jones prince', 'architecture for humanity', 'arielle ford', 'arnold rampersad', 'art spielman', 'arthur goldhammer', 'arthur h. samuelson', 'arthur morey', 'arthur raleigh humphreys', 'astre mithrandir', 'atul gawande', 'audrey penn', 'august wilson', 'austin tichenor', 'ayako watanabe', 'b.k. beckwith', 'bambi eloriaga', 'barbara a. turner', 'barbara ann brennan', 'barbara caruso', 'barbara kerley', 'barbara leonie picard', 'barbara reynolds', 'bard thompson', 'barrie d. coate', 'barrie trinkle', 'barry hughart', 'barry miles', 'barry r. cournoyer', 'barry schwartz', 'barry z. posner', 'bart d. ehrman', 'bartholomew gill', 'basilio losada', 'benjamin beard', 'benjamin chaud', 'benjamin f. fisher', 'benjamin martinez', 'bennett cerf', 'berlitz publishing company', 'bernard cohen', 'berta platas', 'beryl markham', 'beth a. jones', 'beth dunfey', 'beth kendrick', 'betty david', 'betty neels', 'beverly daniel tatum', 'bill fawcett', 'bill hybels', 'bill miller', 'bill moyers', 'bill pittman', 'bill plaschke', 'billie letts', 'binjamin w. segel', 'blaise pascal', 'blake nevius', 'bob carrau', 'bob hines', 'bob mcleod', 'bob phillips', 'bobby henderson', 'bonnie kime scott', 'bonnie timmons', 'brad inwood', 'brenda jackson', 'breon mitchell', 'bret norris', 'brian ching', 'brian doyle', 'brian m. sammons', 'brian selznick', 'brian w. aldiss', 'brian yoon', 'brigitte lefevre', 'brooke allen', 'bruce catton', 'bruce harbert', 'bruce kuklick', 'bruce spizer', 'bryan j.l. glass', 'bryan talbot', 'buzz bissinger', 'c. hassell bullock', 'c.b. mordan', 'c.d.c. reeve', 'c.f. smith', 'c.h. sisson', 'c.j. cherryh', 'c.s. harris', 'camellia panjabi', 'cameron sinclair', 'candida höfer', 'canon doyle', 'cara black', 'cara lockwood', 'carl f. hovde', 'carla jungquist', 'carlene fredericka brennen', 'carlo capararo', 'carlos a. schwantes', 'carlos marighella', 'carol belanger grafton', 'carol bloom stevens', 'carol c. haber', 'carol christensen', 'carol drinkwater', 'carol heyer', 'carol howard', 'carol kolb', 'carol lloyd', 'carol t. christ', 'carole nelson douglas', 'carolyn andrews', 'carolyn brown', 'carolyn dewald', 'catherine cobham', 'catherynne m. valente', 'cathleen miller', 'cecil hemley', 'chalmers johnson', 'chandler brossard', 'chaosium inc.', 'charles a. peek', 'charles alexander ro ...
#   .format(sorted(unknown, key=str)))
# /usr/local/lib/python3.6/dist-packages/sklearn/preprocessing/_label.py:987: UserWarning: unknown class(es) ['msa', 'swe'] will be ignored
#   .format(sorted(unknown, key=str)))
# /usr/local/lib/python3.6/dist-packages/sklearn/preprocessing/_label.py:987: UserWarning: unknown class(es) ['1st book library', '1st world library', 'abdo publishing company', 'abraham guillen press', 'abrams', 'ace trade', 'acento editorial', 'adams media', 'aegypan', 'alan rodgers books', 'alderac entertainment group', 'alfabeta bokförlag', 'alianza editorial', 'alison green books', 'alliance publishing', 'alpha books', 'anchor canada', 'ann arbor media', 'arden shakespeare', 'aris and phillips', 'arléa', 'arsenal pulp press', 'ash tree publishing', 'atlantic books (uk)', 'atlantic inc.', 'atlantic monthly press', 'audiotext', 'avon books (p)', 'backinprint.com', 'baker books', 'ballantine books (ny)', 'bantam books inc.', 'bantam starfire', 'bantem press', 'barbour books', 'barefoot books', 'basil blackwell (cambridge ma', 'bbc audiobooks america', 'bcp', 'belknap press of harvard university press', 'bertrand', 'better homes and gardens books', 'between the lines productions', 'bibliolife', 'billboard books', 'black lizard books', 'bloomsbury (nyc)', "bloomsbury children's books", 'bolchazy-carducci publishers', 'book publishing company (tn)', 'boosey & hawkes inc', 'broadway business', 'canadian broadcasting corporation (cbc audio)', 'candlewick', 'catholic book publishing', 'challcrest press', 'challenge press inc.', 'changeling press', 'chosen books', 'chu hartley publishers llc', 'civitas books', 'cmx', 'coffee house press', 'cold spring harbor laboratory press', 'cold spring press', 'collins', 'cornell university press', 'council oak books', 'council press', 'crossroad', 'crown journeys', 'crown publishers', 'círculo de lectores', 'dafina books', 'dante university of america press', 'darton longman & todd', 'david c cook', 'daw sf', 'dc comics vertigo', 'deadite press (eraserhead press)', 'debols!llo', 'dell publishing', 'delmar thomson learning', 'deodand publishing', 'diogenes', 'diogenes verlag', 'distribooks', 'dominion press', 'dover publications (nyc)', 'duckworth publishing', 'dutton adult', 'east bay municipal utility district', 'ecco press', 'edebé', 'el paso norte press', 'enitharmon press', 'eros comix', 'evans brothers', 'everyman chess', 'everyman paperback classics', 'everyman paperbacks', 'f. meiner', 'faber & faber ltd.', 'faber and faber & penguin india', 'fantagraphics books', 'farrar straus and giroux (ny)', 'fasa corp.', 'fellowship for the performance', 'feral house', 'festival books', 'filiquarian publishing llc.', 'fischer (tb.)', 'five star (me)', 'fleming h revell co', 'folio histoire', 'fontana press', 'four ninety-eight productions', 'franklin watts', 'frederick p. lenz foundation for american buddhism', 'ft press', "g. p. putnam's sons", 'gaia books', 'galahad books', 'gale cengage', 'gallery', 'gallimard jeunesse', 'george braziller', 'gollehon books', 'grafton', 'gramedia pustaka utama', 'grand central publishing (formerly warner books)', 'green integer', 'grove', 'grove press black cat', 'grove press open city books', 'grove weidenfeld', 'grupo editorial norma s.a.', 'gürze books', 'hackett publishing company', 'hackett publishing company (indianapolis in)', 'hal leonard pub corp', 'harbor press', 'harcourt brace & company', 'harlequin american romance', "harlequin readers' choice", 'harper trophy', 'harperpaperbacks', 'harperprism', 'harpersanfrancisco', 'harpervoyager', 'harrison house', 'harvard university press (cambridge ma)', 'hazelden publishing', 'headline book pub ltd', 'heinemann-octopus', 'henry holt & company', 'hesperus press', 'hippo', 'hodder audio', 'hodder mobius', 'houghton mifflin harcourt p', 'house of anansi press', 'howard publishing co', 'imprint academic', 'indigo', 'inner city books', 'insel', 'international publishers', 'intervarsity press', 'island press', 'ivp academic', 'ivp books', 'jessica kingsley publishers', 'joshua odell editions', 'julie andrews collection', 'k.g. saur verlag', 'kindle', 'kodansha america', 'konemann', 'kyle books', 'laffont', 'larousse ...
#   .format(sorted(unknown, key=str)))
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:13: FutureWarning: Series.dt.weekofyear and Series.dt.week have been deprecated.  Please use Series.dt.isocalendar().week instead.
#   del sys.path[0]
# /usr/local/lib/python3.6/dist-packages/sklearn/preprocessing/_label.py:987: UserWarning: unknown class(es) ['a.t. hatto', 'aaron rosenberg', 'abdul rahman munif', 'adam golaski', 'adam mccauley', 'adolfo pérez perdomo', 'adrian lester', 'aimé césaire', 'al gore', 'alan brennert', 'alan hausman', 'alec maclellan', 'alec stevens', 'alex constantine', 'alfred bester', 'alfred uhry', 'algernon blackwood', 'alice hudson', 'allan cameron', 'allen w. wood', 'allison markin powell', 'alvin l. reid', 'amanda eyre ward', 'ambrose bierce', 'amy cotler', 'amy sickels', 'ana alcaina', 'ana maría de la fuente', 'andre dubus', 'angel m.y. lin', 'angela barrett', 'anita desai', 'ann romines', 'annette smith', 'anthony curtis', 'anthony d. pellegrini', 'anthony robbins', 'antonio polito', 'arnold rampersad', 'arthur j. roth', 'b. deutsch', 'bagram ibatoulline', 'barb jernigan', 'barbara bottner', 'barbara delaplace', 'barbara newman', 'barry eisler', 'barry glassner', 'barry n. malzberg', 'ben carson', 'ben oliver', 'bernard taper', 'betty mccollum', 'bill phillips', 'bill potter', 'billy mills', 'blake cahoon', 'bob marley', 'bob mccabe', 'bob shaw', 'bobbi smith', 'bonnie burton', 'brad meltzer', 'brandon badeaux', 'brenda g. bare', 'brendan connell', 'brian campbell', 'brian unger', 'brian w. aldiss', 'brice matthieussent', 'bruce alvin king', "bryan lee o'malley", 'bryan talbot', 'bryan w. van norden', 'c.d.c. reeve', 'c.f. smith', 'c.l. moore', 'c.m. kornbluth', 'caitlin brennan', 'camino estañ requeni', 'carl dennis', 'carl sandburg', 'carlos alberto gardini', 'carlos garzon', 'carlos meglia', 'carlton mellick iii', 'carme camps monf', 'carol adrienne', 'carol marinelli', 'cary f. baynes', 'caryl emerson', 'cecil murphey', 'chantal mouffe', 'charles a. coulombe', 'charles allen', 'charles lockwood', 'charlotte hughes', 'chris garratt', 'chris seay', 'chris terry', 'chris van dusen', 'christophe claro', 'christopher biffle', 'cindy crawford', 'cindy pearlman', 'claudia carroll', 'colin smith', 'colleen sexton', 'colum mccann', "constance o'banyon", 'corinna milborn', 'cornelius agrippa', 'cristina garcía', 'curt meyer-clason', "d'israeli", 'd.j. enright', 'd.t. max', 'd.w. moffett', 'daigo shinma', 'dan welch', 'daniel j. boorstin', 'daniel leighton', 'daphne hardy', 'darcey bussell', 'darren aronofsky', 'dave robinson', 'david a. black', 'david attwell', 'david bowie', 'david brett', 'david gates', 'david giordano', 'david heinemeier hansson', 'david ignatow', 'david lazar', 'david lindsay-abaire', 'david lodge', 'david loftus', 'david mcduff', 'david p. dewitt', 'david schneider', 'david thomas lord', 'david timson', 'david w. lightfoot', 'debra cowan', 'deirdre bair', 'dermot moran', 'devon w. carbado', 'diana vreeland', 'diane dawson hearn', 'don e. fehrenbacher', 'donald hall', 'donald t. phillips', 'donald tyson', 'donald weise', 'donaldo macedo', 'doris kearns goodwin', 'doug braithwaite', 'doug stanton', 'douglas c. kenney', 'duncan eagleson', 'duncan wu', 'dwight a. mcbride', 'dōgen', 'e.j. wagner', 'ed zotti', 'edgar c. marchant', "edgar parin d'aulaire", 'edna hatlestad hong', 'edna st. vincent millay', 'edward countryman', 'edward g. brown', 'edward gibbon', 'edwin m. curley', 'efrem smith', 'eilat negev', 'el hagahn', 'elaine barbieri', 'elan golomb', 'eliot ness', 'elizabeth c. economy', 'elizabeth f. cooke', 'elizabeth silverthorne', 'ellen guon', 'ellen h. bleiler', 'ellen meloy', 'elsa mateo', 'emilie griffin', 'enrico marini', 'eric bentley', 'eric hansen', 'eric homberger', 'eric klinenberg', 'erica funkhouser', 'erin mccarthy', 'ernesto laclau', 'ernst e. jonas', 'evelyn c. white', 'evelyn rogers', "everyman's library", "fitz-james o'brien", 'fleur adcock', 'francine du plessix gray', 'francisco rodriguez de lecea', 'frank macshane', 'frank mcconnell', 'frank p. incropera', 'fred anderson', 'freda titford', 'frederick burkhardt', 'frederick charles copleston', 'frederick deluvier', 'frederick p. lenz', 'frederick seitz ...
#   .format(sorted(unknown, key=str)))
# /usr/local/lib/python3.6/dist-packages/sklearn/preprocessing/_label.py:987: UserWarning: unknown class(es) ['ale'] will be ignored
#   .format(sorted(unknown, key=str)))
# /usr/local/lib/python3.6/dist-packages/sklearn/preprocessing/_label.py:987: UserWarning: unknown class(es) ['abacus books', 'abingdon press', 'amherst media', 'ann arbor media', 'applause theatre & cinema book publishers', 'ava publishing', 'avoneos', 'berkley books (ny)', 'berkley prime crime books', 'birlinn ltd', 'blanvalet taschenbuch', 'blanvalet verlag gmbh', 'bloomsbury childrens books', 'bloomsbury paperbacks', 'bolchazy-carducci publishers', 'book publishing company', 'booket', 'bookspan', 'brava', 'charnwood', 'chelsea house publishers', "children's press(ct)", 'cisne', 'cistercian publications', 'columbia pictures pubns', 'comicslit', 'cornell university press', 'cq press', 'crossroad', 'cátedra', 'doubleday & company inc.', 'doubleday canada', 'downtown press', 'dramatists play service inc.', 'ebury', 'eraserhead press', 'fawcett crest books', 'feral house', 'festival', 'filiquarian publishing llc.', 'frederick p. lenz foundation for american buddhism', 'golden gryphon press', 'grand central publishing (formerly warner books)', 'graphics press', 'grove press (nyc)', "hachette children's", 'hal leonard publishing corporation', 'harcourt brace jovanovich (ny)', 'harper element', 'harpercollins (sanfrancisco)', 'harpercollins publishers inc.', 'harpertorch (an imprint of harpercollins publishers)', 'haus publishing', 'hci', 'heinemann', 'heinemann drama', 'high point media', 'holt rinehart and winston inc.', 'houghton mifflin harcourt p', 'howard university press', 'indypublish.com', 'ivp books', 'kregel academic & professional', 'lama foundation (san cristobal nm)', 'liguori publications', 'lippincott williams & wilkins', 'livre de poche', 'loeb classical library 307', 'london : collins 2004.', 'loveswept', 'manning publications', 'mayfield publishing company (ny)', 'mcfarland & company', 'michael joseph ltd.', "michael o'mara", 'mills & boon', 'minnesota heritage publishing', 'mit press (ma)', 'new harbinger publications', 'nimble books', 'nostalgia ventures', 'onyx books', 'orion publishing co', 'owlet paperbacks', 'panther', 'pelican publishing company', 'penguin audio uk', 'penguin press', 'penguin putnam', 'peter owen ltd', 'picture book studio ltd', 'piemme', 'pinter & martin ltd', 'plaza & janés', 'plaza & janés editores s.a.', 'poisoned pen press', 'poppy', 'puzzle-via magna', 'quarry press', 'random house para ninos', 'rbooks', 'record', 'regan books', 'replica books', 'rh audio price-less', 'roc trade', 'ronin publishing (ca)', 'russell enterprises', 'scholastic nonfiction', 'shaw', 'stone bridge press', 'tachyon publications', "teacher's pet publications inc.", 'thomas publications (pa)', 'time warner books uk', 'time warner paperbacks', 'titan', 'transaction publishers', 'treat enterprises', 'turtleback books distributed by demco media', 'twenty-first century books (ct)', 'university of minnesota press', 'usborne books', 'vendome press', 'viking compass (non-classics)', 'viking juvenile', 'vintage books a division of random house', 'virago uk', 'vision forum', 'walker & company', 'walter de gruyter', 'warner', 'watson-guptill', 'wesleyan university press', 'windsor golden series', 'winter on the farm (my first little house)', 'zeta bolsillo', '時報出版', '英文漢聲出版股份有限公司'] will be ignored
#   .format(sorted(unknown, key=str)))
# trainData: (6378, 15974)
# testData: (2734, 15974)
# evaluateData: (1000, 15974)
#
# Shape checking:  True
#
#
#
# (6378, 15973) (6378,)
# (2734, 15973) (2734,)
# (1000, 15973) (1000,)

# %% [markdown]
# ## Train Model

# %%
model = keras.Sequential([
      layers.Dense(128, activation='relu'),
      layers.Dense(64, activation='relu'),
      layers.Dense(64, activation='relu'),
      layers.Dense(1)
  ])

model.compile(loss=tf.keras.losses.MeanSquaredError(), optimizer=tf.keras.optimizers.Adam(0.001))
history = model.fit(
    XTrain, yTrain,
    validation_split=0.2,
    verbose=0, epochs=150)

model.summary()
# Out:
# WARNING:tensorflow:Layer dense_11 is casting an input tensor from dtype float64 to the layer's dtype of float32, which is new behavior in TensorFlow 2.  The layer has dtype float32 because its dtype defaults to floatx.
#
# If you intended to run this layer in float32, you can safely ignore this warning. If in doubt, this warning is likely only an issue if you are porting a TensorFlow 1.X model to TensorFlow 2.
#
# To change all layers to have dtype float64 by default, call `tf.keras.backend.set_floatx('float64')`. To change just this layer, pass dtype='float64' to the layer constructor. If you are the author of this layer, you can disable autocasting by passing autocast=False to the base Layer constructor.
#
# Model: "sequential_3"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# dense_11 (Dense)             (None, 128)               2044672
# _________________________________________________________________
# dense_12 (Dense)             (None, 64)                8256
# _________________________________________________________________
# dense_13 (Dense)             (None, 64)                4160
# _________________________________________________________________
# dense_14 (Dense)             (None, 1)                 65
# =================================================================
# Total params: 2,057,153
# Trainable params: 2,057,153
# Non-trainable params: 0
# _________________________________________________________________

# %% [markdown]
# ## Evaluate model

# %%
# yPredict = model.predict(XTest)
# mse = mean_squared_error(yTest, yPredict)

result = model.evaluate(XTest, yTest, verbose=0)
print("Neural Network with TF-IDF with - Mean Squared Error: ", round(result, 5))
# Out:
# Neural Network with TF-IDF with - Mean Squared Error:  0.10931

# %%
plt.figure(dpi=120)
plt.plot(history.history['loss'], label='loss')
plt.plot(history.history['val_loss'], label='val_loss')
plt.ylim([0, 1])
plt.xlabel('Epoch')
plt.ylabel('Error [MSE]')
plt.legend()
plt.grid(True)

# %% [markdown]
# ## Output submit assignment file

# %%
yEvaluatePredict = model.predict(XEvaluate)

output = evaluatingData
output['average_rating'] = yEvaluatePredict

output.shape
output.head()

output.to_csv('output.csv')
output.describe()
# Out:
#        average_rating  ...  publication_date_day
# count     1000.000000  ...           1000.000000
# mean         3.970057  ...             11.766000
# std          0.419773  ...             10.472293
# min          3.328446  ...              1.000000
# 25%          3.854172  ...              1.000000
# 50%          3.995846  ...             10.000000
# 75%          4.033588  ...             21.000000
# max         16.052357  ...             31.000000
#
# [8 rows x 9 columns]
